# %% [raw]
# ---
# title: About NASCENT-Peru
# format: html
# ---

# %% [markdown]
# ## Team
#
# ```{html}
# <details>
# <summary>ETH Zurich</summary>
# <table>
#     <colgroup>
#        <col span="1" style="width: 15%;">
#        <col span="1" style="width: 85%;">
#     </colgroup>
#   <tbody>
#     <tr>
#     <td><img src="Adrienne.jpg" class="portrait"/></td>
#     <td><a href="https://plus.ethz.ch/chair/people/person-detail.html?persid=56793">Prof. Dr. Adrienne Grêt-Regamey</a></td>
#     </tr>
#     <tr>
#     <td><img src="loic.jpeg" class="portrait"/></td>
#     <td><a href="https://usys.ethz.ch/en/people/profile.loic-pellissier.html">Prof. Dr. Loïc Pellissier</a></td>
#     </tr>
#     <tr>
#     <td><img src="Ben.jpg" class="portrait"/></td>
#     <td><a href="https://irl.ethz.ch/de/people/person-detail.MjgyMjA5.TGlzdC8xNzM4LC0xMzk1OTgzMDM3.html">Benjamin Black</a></td>
#     </tr>
#     <tr>
#     <td><img src="Chenyu.jpg" class="portrait"/></td>
#     <td><a href="https://baug.ethz.ch/departement/personen/mitarbeiter/personen-detail.MjY0MDc2.TGlzdC82NzksLTU1NTc1NDEwMQ==.html">Chenyu Shen</a></td>
#     </tr>
#     </tr>
#     <tr>
#     <td><img src="Manuel.jpg" class="portrait"/></td>
#     <td><a href="https://plus.ethz.ch/de/die-gruppe/personen/person-detail.MjM2NjYz.TGlzdC8xMjQyLDE0MzMyMTIxNTg=.html">Manuel Kurmann</a></td>
#     </tr>
#   </tbody>
# </table>
# </details>
# ```
#
# ```{=html}
# <details>
# <summary>Wyss Academy for Nature</summary>
# <table>
#     <colgroup>
#        <col span="1" style="width: 15%;">
#        <col span="1" style="width: 85%;">
#     </colgroup>
#   <tbody>
#     <tr>
#     <td><img src="Edouard.jpg" class="portrait"/></td>
#     <td><a href="https://www.wyssacademy.org/team/prof.-dr.-edouard-davin?">Prof. Dr. Edouard Davin</a></td>
#     </tr>
#     <tr>
#     <td><img src="Armando.jpg" class="portrait"/></td>
#     <td><a href="https://www.wyssacademy.org/team/prof.-dr.-armando-vald%C3%A9s-vel%C3%A1squez">Prof. Dr. Armando Valdés-Velásquez</a></td>
#     </tr>
#     <tr>
#     <td><img src="JanGoepel.jpg" class="portrait"/></td>
#     <td><a href="https://www.wyssacademy.org/team/dr.-jan-g%C3%B6pel?">Dr. Jan Göpel</a></td>
#     </tr>
#     <tr>
#     <td><img src="Miguel.jpg" class="portrait"/></td>
#     <td><a href="https://www.wyssacademy.org/team/miguel-saravia?">Miguel Saravia</a></td>
#     </tr>
#   </tbody>
# </table>
# </details>
# ```
#
# ```{=html}
# <details>
# <summary>Université de Lausanne</summary>
# <table>
#     <colgroup>
#        <col span="1" style="width: 15%;">
#        <col span="1" style="width: 85%;">
#     </colgroup>
#   <tbody>
#     <tr>
#     <td><img src="antoine.jpeg" class="portrait"/></td>
#     <td><a href="https://www.unil.ch/dee/en/home/menuguid/people/group-leaders/prof-antoine-guisan.html">Prof. Dr. Antoine Guisan</a></td>
#     </tr>
#   </tbody>
# </table>
# </details>
# ```
#
# ```{=html}
# <details>
# <summary>Université Grenoble Alpes</summary>
# <table>
#     <colgroup>
#        <col span="1" style="width: 15%;">
#        <col span="1" style="width: 85%;">
#     </colgroup>
#   <tbody>
#     <tr>
#     <td><img src="Ignacio.jpg" class="portrait"/></td>
#     <td><a href="https://globalyoungacademy.net/ipalomo/">Dr. Ignacio Palomo</a></td>
#     </tr>
#   </tbody>
# </table>
# </details>
# ```
#
#
#
# ## Finances
#
# The project is funded as part of the Biodiversity and Ecosystem Services Scenario modelling challenge financed by the Swiss Re Foundation, Swiss Re Institute,Swiss Re Corporate Solutions, EY, WWF and the AXA Research Fund.
#
# <img src="finances.png" style="height: 100%; width: 100%;"/>
#
# ----
#
# ## Contact
# <a href="https://www.w3schools.com">Benjamin Black</a>, ETH Zurich, PLUS
